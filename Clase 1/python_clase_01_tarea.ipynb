# %% [markdown]
# # 🏠 Tarea — Clase 1: Fundamentos de Python
#
# **Estudiante:** _escribe tu nombre aquí_
# **Fecha de entrega:** _escribe la fecha aquí_
#
# ---
#
# ### 📌 Instrucciones
#
# - Escribe tu solución **únicamente** en la celda marcada con ✍️.
# - Ejecuta cada celda con **Shift + Enter** para probar tu código.
# - Si tu código no funciona a la primera, ¡no te rindas! Leer el mensaje de error te ayuda a encontrar el problema.
# - Puedes consultar el notebook de la clase, pero intenta resolverlo primero sin mirarlo.
#
# ### 🏅 Niveles de dificultad
# - 🟢 **Básico** — Un concepto a la vez
# - 🟡 **Intermedio** — Combina dos conceptos
# - 🔴 **Reto** — Piensa paso a paso antes de escribir
#
# ---

# %% [markdown]
# ## ✏️ Parte 1: `print()` y texto

# %% [markdown]
# ### 🟢 Ejercicio 1 — Mi presentación
#
# Usa `print()` para mostrar exactamente **5 líneas** con información sobre ti:
#
# ```
# Línea 1: Tu nombre completo
# Línea 2: Tu profesión o rol
# Línea 3: La ciudad donde vives
# Línea 4: Tu materia o tema favorito
# Línea 5: Una meta que tienes este año
# ```
#
# **Ejemplo de salida:**
# ```
# Me llamo Ana García
# Soy profesora de tecnología
# Vivo en Bogotá
# Mi tema favorito es la robótica
# Este año quiero aprender a programar
# ```

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟢 Ejercicio 2 — Separador visual
#
# Los programas a veces necesitan separar secciones visualmente. Usa `print()` para reproducir este patrón exacto:
#
# ```
# ********************
# *   BIENVENIDOS    *
# ********************
# ```
#
# > 💡 **Pista:** son exactamente 20 asteriscos en la primera y última línea. Cuenta bien.

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟢 Ejercicio 3 — print() con números
#
# Imprime los siguientes valores **en este orden**, cada uno en su propia línea:
# - El número de estudiantes en tu salón
# - El número de materias que enseñas (o que tienes)
# - La nota máxima posible (10)
# - El año actual
# - El valor de pi con dos decimales (3.14)
#
# > 💡 **Pista:** los números van sin comillas. El texto sí lleva comillas.

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ---
# ## ✏️ Parte 2: Variables y tipos de datos

# %% [markdown]
# ### 🟢 Ejercicio 4 — Creando variables
#
# Crea una variable para cada uno de estos datos y luego imprímelos todos:
#
# | Variable | Tipo | Valor sugerido |
# |----------|------|----------------|
# | `nombre_colegio` | texto | El nombre de tu colegio |
# | `numero_grados` | entero | Cuántos grados tiene el colegio |
# | `jornada_horas` | decimal | Cuántas horas dura la jornada |
# | `tiene_sala_sistemas` | booleano | ¿Tiene sala de sistemas? |
#
# Imprime cada variable en una línea diferente.

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟢 Ejercicio 5 — ¿Qué tipo de dato es?
#
# Ya están creadas estas variables. Tu tarea es usar `type()` para descubrir e imprimir el tipo de cada una. Después, en el comentario al lado de cada `print()`, escribe con tus palabras qué tipo es (por ejemplo: `# esto es texto`).
#
# > 💡 **Pista:** los tipos posibles son `str`, `int`, `float` y `bool`.

# %%
# Las variables ya están — tú solo agrega los print(type(...))
a = "Aprender Python"
b = 2026
c = 4.5
d = True
e = 0
f = "100"

# ✍️ Imprime el tipo de cada variable aquí:
# OJO: ¿e y f son del tipo que esperabas? Fíjate bien.

# %% [markdown]
# ### 🟡 Ejercicio 6 — f-strings: carta de presentación
#
# Usando las variables ya definidas abajo, construye una mini carta de presentación con **f-strings**. El texto final debe ser:
#
# ```
# Hola, me llamo Ana García y tengo 35 años.
# Soy profesora y trabajo en el Colegio Nacional.
# Llevo 8 años en la docencia.
# ¿Soy titulada? True
# ```
#
# No escribas los valores directamente en el texto — usa las variables con `{ }`.

# %%
# Variables dadas — no las modifiques
nombre = "Ana García"
edad = 35
profesion = "profesora"
colegio = "Colegio Nacional"
anos_experiencia = 8
es_titulada = True

# ✍️ Escribe los print() con f-strings aquí:

# %% [markdown]
# ### 🟢 Ejercicio 7 — Variables que cambian
#
# Sigue las instrucciones en los comentarios del código:

# %%
# Paso 1: crea una variable 'puntos' con valor 0 e imprímela


# Paso 2: súmale 10 a puntos e imprime el nuevo valor


# Paso 3: multiplica puntos por 2 e imprime


# Paso 4: réstale 5 e imprime


# Paso 5: imprime un mensaje final con f-string:
# "Puntaje final: X puntos"

# %% [markdown]
# ---
# ## ✏️ Parte 3: Operaciones matemáticas

# %% [markdown]
# ### 🟢 Ejercicio 8 — La calculadora del docente
#
# Un docente necesita calcular varias cosas. Usa variables y operaciones matemáticas para encontrar cada resultado:
#
# ```python
# estudiantes_por_grado = 28
# numero_de_grados = 4
# costo_cuaderno = 4500
# cuadernos_por_estudiante = 3
# ```
#
# Calcula e imprime:
# 1. Total de estudiantes en el colegio
# 2. Total de cuadernos necesarios (para todos)
# 3. Costo total de todos los cuadernos
# 4. Si se reparten los cuadernos en 6 cajas iguales, ¿cuántos van en cada caja? (usa división entera `//`)
# 5. ¿Cuántos cuadernos sobran de ese reparto? (usa módulo `%`)

# %%
# Variables dadas
estudiantes_por_grado = 28
numero_de_grados = 4
costo_cuaderno = 4500
cuadernos_por_estudiante = 3

# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟡 Ejercicio 9 — Conversor de tiempo
#
# Una clase dura **225 minutos** en total (el día completo de clases). Calcula:
#
# 1. ¿Cuántas horas completas son? (división entera)
# 2. ¿Cuántos minutos sobran después de las horas completas? (módulo)
# 3. ¿Cuántos segundos son 225 minutos en total?
#
# Imprime los resultados con f-strings en frases completas.
#
# **Salida esperada:**
# ```
# 225 minutos son 3 horas y 45 minutos.
# En segundos: 13500 segundos.
# ```
#
# > 💡 **Pista:** 1 minuto = 60 segundos.

# %%
# ✍️ Tu solución aquí:
minutos_totales = 225

# %% [markdown]
# ### 🟡 Ejercicio 10 — Promedio ponderado
#
# En tu colegio las notas tienen diferente peso:
#
# | Evaluación | Nota | Peso |
# |-----------|------|------|
# | Trabajo en clase | 7.0 | 30% |
# | Examen parcial | 8.5 | 30% |
# | Proyecto final | 9.0 | 40% |
#
# Calcula la **nota final ponderada** usando esta fórmula:
# `final = (nota1 * peso1) + (nota2 * peso2) + (nota3 * peso3)`
#
# Los pesos van como decimales: 30% = 0.30
#
# Imprime la nota final con **2 decimales**.
#
# > 💡 **Pista:** para imprimir con 2 decimales en un f-string usa `{variable:.2f}`

# %%
# ✍️ Tu solución aquí:
nota_trabajo = 7.0
nota_examen = 8.5
nota_proyecto = 9.0

# %% [markdown]
# ---
# ## ✏️ Parte 4: `input()` — Entrada del usuario

# %% [markdown]
# ### 🟢 Ejercicio 11 — Saludo personalizado
#
# Escribe un programa que:
# 1. Pida el nombre del usuario
# 2. Pida su materia favorita
# 3. Imprima un saludo personalizado usando ambos datos
#
# **Salida esperada:**
# ```
# ¿Cómo te llamas? María
# ¿Cuál es tu materia favorita? Tecnología
# ¡Hola, María! Qué bueno que te gusta Tecnología 🎉
# ```

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟡 Ejercicio 12 — Calculadora de propina
#
# Escribe un programa que pida:
# 1. El valor total de una cuenta en pesos
# 2. El porcentaje de propina que quiere dar (ejemplo: 10, 15, 20)
#
# Y calcule e imprima:
# - El valor de la propina
# - El total a pagar (cuenta + propina)
#
# **Salida esperada:**
# ```
# ¿Cuánto fue la cuenta? 85000
# ¿Qué % de propina quieres dar? 15
#
# Propina (15%): $12,750
# Total a pagar: $97,750
# ```
#
# > 💡 **Pistas:**
# > - La cuenta y el porcentaje llegan como texto — conviértelos con `float()` e `int()`.
# > - Para el formato con coma de miles: `{valor:,.0f}`

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟡 Ejercicio 13 — Año de nacimiento
#
# Escribe un programa que pida la **edad** del usuario y calcule:
# 1. El año aproximado en que nació (usa 2026 como año actual)
# 2. Cuántos años le faltan para cumplir 100
# 3. En qué año cumplirá 100
#
# **Salida esperada:**
# ```
# ¿Cuántos años tienes? 35
#
# Naciste aproximadamente en el año 1991.
# Te faltan 65 años para cumplir 100.
# Cumplirás 100 años en el 2091.
# ```

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ---
# ## ✏️ Parte 5: Condicionales `if / elif / else`

# %% [markdown]
# ### 🟢 Ejercicio 14 — ¿Aprobó o reprobó?
#
# Dado el promedio ya definido, escribe un `if/else` que imprima si el estudiante aprobó o reprobó. La nota mínima para aprobar es **6.0**.
#
# Prueba cambiando el valor de `promedio` para verificar que funciona en ambos casos.

# %%
promedio = 5.8    # cambia este valor para probar

# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟢 Ejercicio 15 — Clasificador de edades
#
# Escribe un programa que lea una edad e imprima a qué grupo pertenece según esta tabla:
#
# | Edad | Grupo |
# |------|-------|
# | 0 - 12 | Niño/a |
# | 13 - 17 | Adolescente |
# | 18 - 59 | Adulto/a |
# | 60 o más | Adulto/a mayor |
#
# > 💡 **Pista:** necesitarás `elif` para los casos intermedios.

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟡 Ejercicio 16 — Semáforo de notas
#
# Pide una nota al usuario y muestra el color del semáforo según el rendimiento:
#
# | Nota | Color | Mensaje |
# |------|-------|---------|
# | 9.0 – 10.0 | 🟢 Verde | Rendimiento excelente |
# | 7.0 – 8.9 | 🟡 Amarillo | Rendimiento bueno |
# | 6.0 – 6.9 | 🟠 Naranja | Rendimiento suficiente |
# | Menor de 6.0 | 🔴 Rojo | Necesita refuerzo |
#
# Si el usuario escribe un número fuera del rango 0–10, muestra:
# `"⚠️ Nota inválida. Debe estar entre 0 y 10."`
#
# > 💡 **Pista:** verifica primero si la nota es válida antes de clasificarla. Necesitarás `and` para la condición del rango.

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ### 🟡 Ejercicio 17 — ¿Puedo inscribirme al taller?
#
# Un taller de robótica tiene estas condiciones para inscribirse:
# - El estudiante debe tener **entre 12 y 17 años** (inclusive)
# - Debe tener un **promedio mayor o igual a 7.0**
# - El taller es solo para estudiantes del **turno mañana**
#
# Pide los 3 datos al usuario e imprime si puede inscribirse o no. Si no puede, dile **cuál condición no cumple** (puede ser más de una).
#
# > 💡 **Pista:** usa variables booleanas intermedias para guardar cada condición por separado. Ejemplo:
# > ```python
# > cumple_edad = (edad >= 12 and edad <= 17)
# > ```

# %%
# ✍️ Tu solución aquí:

# %% [markdown]
# ---
# ## 🔴 Parte 6: Retos integradores
#
# > Estos ejercicios combinan **todo** lo de la clase. Antes de escribir código, lee el enunciado completo y piensa los pasos en papel.

# %% [markdown]
# ### 🔴 Reto 1 — Mi calculadora de notas
#
# Crea un programa que:
#
# 1. Pida el **nombre** del estudiante
# 2. Pida **4 notas** (una por una)
# 3. Calcule el **promedio**
# 4. Determine la **situación académica** según:
#    - Promedio >= 9.0 → `"Matrícula de honor 🏆"`
#    - Promedio >= 7.0 → `"Aprobado con mérito ✅"`
#    - Promedio >= 6.0 → `"Aprobado ✅"`
#    - Promedio < 6.0 → `"Reprobado ❌"`
# 5. Imprima un **informe final** con todos los datos
#
# **Salida esperada:**
# ```
# --- INFORME ACADÉMICO ---
# Estudiante: Lucía Torres
# Notas: 8.0, 9.5, 7.5, 8.0
# Promedio: 8.25
# Situación: Aprobado con mérito ✅
# -------------------------
# ```

# %%
# ✍️ Tu solución aquí:
# Sugerencia: resuelve paso a paso
# Paso 1 — pedir nombre

# Paso 2 — pedir 4 notas (recuerda convertirlas a float)

# Paso 3 — calcular promedio

# Paso 4 — determinar situación con if/elif/else

# Paso 5 — imprimir informe

# %% [markdown]
# ### 🔴 Reto 2 — Planificador de clase
#
# Crea un programa que ayude a planificar una clase. Debe pedir:
#
# 1. El **nombre de la materia**
# 2. El **número de estudiantes**
# 3. La **duración total de la clase en minutos**
# 4. Si se incluye **trabajo en grupo** (`"si"` o `"no"`)
#
# Con esos datos, el programa calcula e imprime:
# - Cuántos minutos hay por estudiante si todos participaran individualmente
# - Si la clase es menor a 45 minutos → `"Clase corta: enfócate en un solo tema"`
#   Si es entre 45 y 90 → `"Clase estándar: puedes incluir actividad práctica"`
#   Si supera 90 min → `"Clase larga: planea al menos un descanso"`
# - Si respondió `"si"` al trabajo en grupo: calcula cuántos grupos de 4 se pueden formar y cuántos estudiantes quedarían sin grupo completo
#
# > 💡 **Pistas:**
# > - Para comparar texto usa `== "si"` (en minúsculas).
# > - Grupos completos → división entera `//`. Estudiantes restantes → módulo `%`.

# %%
# ✍️ Tu solución aquí:
# Sugerencia: escribe los pasos como comentarios antes de codificar
# Paso 1 — pedir datos

# Paso 2 — calcular minutos por estudiante

# Paso 3 — clasificar duración de la clase

# Paso 4 — si hay trabajo en grupo, calcular grupos

# Paso 5 — imprimir resumen

# %% [markdown]
# ---
# ## 💭 Reflexión final
#
# Responde en las celdas de abajo con tus propias palabras (no hay respuesta incorrecta):

# %% [markdown]
# **1. ¿Qué ejercicio de esta tarea te resultó más difícil? ¿Por qué crees que fue así?**
#
# _Escribe aquí tu respuesta..._

# %% [markdown]
# **2. ¿Hubo algún concepto que al hacer los ejercicios te quedó más claro que en la clase?**
#
# _Escribe aquí tu respuesta..._

# %% [markdown]
# **3. ¿Se te ocurre alguna situación de tu trabajo como profesora donde podrías usar alguno de estos programas?**
#
# _Escribe aquí tu respuesta..._

# %% [markdown]
# ---
# ## ✅ Checklist antes de entregar
#
# Antes de enviar tu tarea, verifica que:
#
# - [ ] Escribí mi nombre al inicio del notebook
# - [ ] Ejecuté todas las celdas con Shift + Enter
# - [ ] Todos los ejercicios muestran una salida (ninguno está vacío)
# - [ ] Intenté los retos integradores
# - [ ] Respondí las 3 preguntas de reflexión
#
# ---
# **¡Mucho éxito! 💪 Recuerda: los errores son parte del aprendizaje. Si algo no funciona, lee el mensaje de error — siempre te da una pista.**
